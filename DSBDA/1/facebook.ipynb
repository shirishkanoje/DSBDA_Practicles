# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("dataset_Facebook.csv", sep=";")

# %%
#describe the dataset
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
# creating Subset

# %%
#subset1
df1= df[['Page total likes', 'Category', 'Post Month', 'Post Weekday']].loc[0:15]
df1
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 1             139441         2          12             3
# 2             139441         3          12             3
# 3             139441         2          12             2
# 4             139441         2          12             2
# 5             139441         2          12             1
# 6             139441         3          12             1
# 7             139441         3          12             7
# 8             139441         2          12             7
# 9             139441         3          12             6
# 10            139441         2          12             5
# 11            139441         2          12             5
# 12            139441         2          12             5
# 13            139441         2          12             5
# 14            138414         2          12             4
# ...

# %%
#subset2
df2=df[['Page total likes', 'Category', 'Post Month', 'Post Weekday']].loc[16:30]
df2
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 16            138414         3          12             3
# 17            138414         1          12             2
# 18            138414         3          12             2
# 19            138414         3          12             1
# 20            138414         2          12             1
# 21            138414         1          12             7
# 22            138414         1          12             7
# 23            138414         3          12             7
# 24            138414         2          12             6
# 25            138458         2          12             6
# 26            138458         2          12             5
# 27            138458         3          12             5
# 28            138895         2          12             5
# 29            138895         1          12             4
# 30            138895         2          12             4

# %%
#subset3
df3=df[['Page total likes', 'Category', 'Post Month', 'Post Weekday']].loc[31:50]
df3
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 31            138895         2          12             3
# 32            138895         3          12             3
# 33            138895         3          12             2
# 34            138895         1          12             2
# 35            138895         2          12             1
# 36            138895         3          12             1
# 37            138895         1          12             7
# 38            138895         2          12             7
# 39            138895         1          12             7
# 40            138895         2          12             6
# 41            138895         1          12             6
# 42            138353         1          12             5
# 43            138353         1          12             5
# 44            138353         1          12             4
# 45            138353         1          12             4
# ...

# %%
#Merge data 
merging=pd.concat([df1,df2,df3])
merging
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 1             139441         2          12             3
# 2             139441         3          12             3
# 3             139441         2          12             2
# 4             139441         2          12             2
# 5             139441         2          12             1
# 6             139441         3          12             1
# 7             139441         3          12             7
# 8             139441         2          12             7
# 9             139441         3          12             6
# 10            139441         2          12             5
# 11            139441         2          12             5
# 12            139441         2          12             5
# 13            139441         2          12             5
# 14            138414         2          12             4
# ...

# %%
#df.sort_vavlues=df.sort_values('Page total likes', ascending= False) ....sort_vslues
df.sort_values(by='Category', ascending =False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 108            136736  Photo         3          10             7          9
# 322            123047  Photo         3           6             2          5
# 331            119198  Photo         3           5             3          5
# 330            120050  Photo         3           5             3         12
# 329            120050  Photo         3           5             4          4
# ..                ...    ...       ...         ...           ...        ...
# 111            136736  Photo         1          10             6          8
# 110            136736  Photo         1          10             6         10
# 339            117764  Photo         1           5             4         10
# 105            137020  Photo         1          10             2          4
# 250            129600  Photo         1           7             7          6
#
# ...

# %%
##Transposing data
df.transpose()  
# OR transposing=df.transpose()....transposing
# Out:
#                       31      32      33      34      35      36      37  \
# Page total likes  138895  138895  138895  138895  138895  138895  138895
# Category               2       3       3       1       2       3       1
# Post Month            12      12      12      12      12      12      12
# Post Weekday           3       3       2       2       1       1       7
#
#                       38      39      40      41      42      43      44  \
# Page total likes  138895  138895  138895  138895  138353  138353  138353
# Category               2       1       2       1       1       1       1
# Post Month            12      12      12      12      12      12      12
# Post Weekday           7       7       6       6       5       5       4
#
#                       45      46      47      48      49      50
# Page total likes  138353  138353  138353  138353  138353  138353
# Category               1       1       1       1       1       2
# ...

# %%
#shape and reshaping 
#shaping
shaping=df.shape
shaping
# Out:
# (20, 4)

# %%
#reshaping
pivot_table=pd.pivot_table(df,index=['Type','Category'],values='share')
print(pivot_table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #reshaping
# ----> 2 pivot_table=pd.pivot_table(df,index=['Type','Category'],values='share')
#       3 print(pivot_table)
#
# NameError: name 'pd' is not defined

# %%
arr=np.array(df[['Post Month','Post Weekday']].head(6))
reshaped=arr.reshape(3,4)
print(reshaped)
# Out:
# [[12  3 12  3]
#  [12  2 12  2]
#  [12  1 12  1]]
